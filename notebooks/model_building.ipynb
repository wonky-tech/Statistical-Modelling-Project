# %% [markdown]
# ## Part 4: Build a regression model.

# %%
# Import the required libraries
import pandas as pd
import numpy as np

# statsmodels modeling library
import statsmodels.api as sm

# plotting libraries
import matplotlib.pyplot as plt
import seaborn as sns

# suppress minor warnings from seaborn
import warnings
warnings.filterwarnings('ignore')

# %%
# Read in the yelp data from part 2 and 3.
yelp_df = pd.read_csv("../data/yelp_poi_data.csv")
yelp_df
# Out:
#        category_alias      category_title                 yelp_id  \
# 0     tapasmallplates  Tapas/Small Plates  _GHNOOJhhjLegiCvzf5V0Q
# 1            scottish            Scottish  _GHNOOJhhjLegiCvzf5V0Q
# 2             british             British  jGLzc9eIUAnfto_5oZ8BMQ
# 3                bars                Bars  rmaH1My396rCYEnL8XQtPg
# 4            scottish            Scottish  rmaH1My396rCYEnL8XQtPg
# ...               ...                 ...                     ...
# 4159            steak         Steakhouses  4B7sGFSBSDjiZMBrYG6AYg
# 4160     cocktailbars       Cocktail Bars  4B7sGFSBSDjiZMBrYG6AYg
# 4161             pubs                Pubs  Oal3XEeDwWeu21lJb-lVgg
# 4162         scottish            Scottish  Oal3XEeDwWeu21lJb-lVgg
# 4163          british             British  Oal3XEeDwWeu21lJb-lVgg
#
#                  yelp_name  yelp_rating  yelp_coordinates.latitude  \
# 0             Ox And Finch          4.7                  55.865654
# ...

# %%
# Assign the appropriate dataframe columns to the dependent and independent variables of the OLS model. 
# In this analysis, we are looking at the relationship between the distance from the bike station to the point of interest and the POI's yelp rating

X = yelp_df['yelp_distance']
y = yelp_df['yelp_rating']

# %% [markdown]
# Provide model output and an interpretation of the results.

# %%
X = sm.add_constant(X) # adding a constant
lin_reg = sm.OLS(y,X)

# %%
model = lin_reg.fit()
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            yelp_rating   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     24.67
# Date:                Mon, 07 Jul 2025   Prob (F-statistic):           7.06e-07
# Time:                        14:24:45   Log-Likelihood:                -3000.6
# No. Observations:                4164   AIC:                             6005.
# Df Residuals:                    4162   BIC:                             6018.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             4.1544      0.015    278.391      0.000       4.125       4.184
# ...

# %% [markdown]
# Above, we see an extremely weak relationship between distance and rating. The relationship is statistically significant at over p = 0.05.

# %% [markdown]
# # Stretch

# %% [markdown]
# How can you turn the regression model into a classification model?
