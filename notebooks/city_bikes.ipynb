# %% [markdown]
# # Part 1: CityBikes

# %% [markdown]
# Send a request to CityBikes for the city of your choice.

# %%
import pandas as pd
import os # use this to access your environment variables
import requests # this will be used to call the APIs
import json

# %%
# Fetch data from the API for Glasgow, UK
url = "http://api.citybik.es/v2/networks/nextbike-glasgow"
response = requests.get(url)
json_data = response.json() # take the JSON data out of the response object
json_data
# Out:
# {'network': {'id': 'nextbike-glasgow',
#   'name': 'Nextbike',
#   'location': {'latitude': 55.8589,
#    'longitude': -4.25549,
#    'city': 'Glasgow',
#    'country': 'GB'},
#   'href': '/v2/networks/nextbike-glasgow',
#   'company': ['Nextbike GmbH'],
#   'system': 'Nextbike',
#   'stations': [{'id': '066c99293af108ece27d9b0436c30cc4',
#     'name': 'Riverside Museum',
#     'latitude': 55.865683,
#     'longitude': -4.305367,
#     'timestamp': '2025-07-01T19:18:19.376003+00:00Z',
#     'free_bikes': 11,
#     'empty_slots': 0,
#     'extra': {'uid': '19738176',
#      'number': '8416',
#      'slots': 6,
#      'bike_uids': ['47041',
#       '823506',
#       '46976',
#       '46961',
#       '46910',
#       '828228',
#       '46562',
#       '46530',
#       '46501',
#       '46409',
#       '829967'],
#      'virtual': False}},
#    {'id': '0a106cbc148d5a0c2535b51c1dbe3b4d',
#     'name': 'Parkhead',
#     'latitude': 55.846524,
#     'longitude': -4.197475,
#     'timestamp': '2025-07-01T19:18:19.377604+00:00Z',
#     'free_bikes': 6,
#     'empty_slots': 0,
#     'extra': {'uid': '150125231',
#      'number': '8470',
#      'slots': 8,
#      'bike_uids': ['82316', '840047', '46722', '46457', '47968', '829955'],
#      'virtual': False}},
#    {'id': '0cc8c09950e1435ee7782478ed292fef',
#     'name': 'Tollcross International Swimming Centre',
#     'latitude': 55.84425,
#     'longitude': -4.176167,
#     'timestamp': '2025-07-01T19:18:19.376951+00:00Z',
#     'free_bikes': 6,
#     'empty_slots': 0,
#     'extra': {'uid': '55599921',
#      'number': '8200',
#      'slots': 6,
#      'bike_uids': ['828253', '46967', '823632', '828964', '823601', '829990'],
#      'virtual': False}},
#    {'id': '0e94d2ad012bff0cf23497963ff5fd77',
#     'name': 'Shields Road',
#     'latitude': 55.845807,
#     'longitude': -4.275232,
#     'timestamp': '2025-07-01T19:18:19.375677+00:00Z',
#     'free_bikes': 1,
#     'empty_slots': 7,
#     'extra': {'uid': '7145152',
#      'number': '8403',
#      'slots': 8,
#      'bike_uids': ['46992'],
#      'virtual': False}},
#    {'id': '101c6cd7749f373507e9444f5222b7f2',
#     'name': 'Shawlands Shopping Centre (Kilmarnock Road)',
#     'latitude': 55.829057,
#     'longitude': -4.282675,
#     'timestamp': '2025-07-01T19:18:19.375152+00:00Z',
#     'free_bikes': 1,
#     'empty_slots': 6,
#     'extra': {'uid': '3812605',
#      'number': '8453',
#      'slots': 8,
#      'bike_uids': ['46830'],
#      'virtual': False}},
#    {'id': '1036625d677b2d21e2aaec9fec0aa3cb',
#     'name': 'Shields Road Subway',
#     'latitude': 55.849924,
#     'longitude': -4.273727,
#     'timestamp': '2025-07-01T19:18:19.377869+00:00Z',
#     'free_bikes': 2,
#     'empty_slots': 8,
#     'extra': {'uid': '262742542',
#      'number': '8482',
#      'slots': 10,
#      'bike_uids': ['829177', '829153'],
#      'virtual': False}},
#    {'id': '10998482c3187c80b1fc322bee154cb6',
#     'name': 'Alexandra Parade (West) - ELECTRIC',
#     'latitude': 55.864472,
#     'longitude': -4.223208,
#     'timestamp': '2025-07-01T19:18:19.375458+00:00Z',
#     'free_bikes': 0,
#     'empty_slots': 8,
#     'extra': {'uid': '6269637',
#      'number': '8468',
#      'slots': 8,
#      'bike_uids': [],
#      'virtual': False}},
#    {'id': '1172741997ccd599fa530bfb8451808c',
#     'name': 'City of Glasgow College (Riverside Campus) - ELECTRIC',
#     'latitude': 55.850554,
#     'longitude': -4.248127,
#     'timestamp': '2025-07-01T19:18:19.374479+00:00Z',
#     'free_bikes': 6,
#     'empty_slots': 0,
#     'extra': {'uid': '349453',
#      'number': '8442',
#      'slots': 6,
#      'bike_uids': ['47376', '828963', '828215', '46719', '46405', '47929'],
#      'virtual': False}},
#    {'id': '1179f511143ae9898181016b37d85b5a',
#     'name': 'Whiteinch Library',
#     'latitude': 55.874555,
#     'longitude': -4.333357,
#     'timestamp': '2025-07-01T19:18:19.377019+00:00Z',
#     'free_bikes': 8,
#     'empty_slots': 0,
#     'extra': {'uid': '55600284',
#      'number': '8203',
#      'slots': 8,
#      'bike_uids': ['829275',
#       '46932',
#       '46888',
#       '46796',
#       '46598',
#       '46585',
#       '829218',
#       '828142'],
#      'virtual': False}},
#    {'id': '12aac9e40a335ee43b231c94972a7a69',
#     'name': 'St Rollox',
#     'latitude': 55.878152,
#     'longitude': -4.242439,
#     'timestamp': '2025-07-01T19:18:19.376656+00:00Z',
#     'free_bikes': 0,
#     'empty_slots': 8,
#     'extra': {'uid': '31234437',
#      'number': '8236',
#      'slots': 8,
#      'bike_uids': [],
#      'virtual': False}},
#    {'id': '1d0ef65099a882d9ca47c5e290a642a9',
#     'name': 'Corkerhill Railway Station',
#     'latitude': 55.836355,
#     'longitude': -4.335149,
#     'timestamp': '2025-07-01T19:18:19.376745+00:00Z',
#     'free_bikes': 9,
#     'empty_slots': 1,
#     'extra': {'uid': '42446574',
#      'number': '8208',
#      'slots': 10,
#      'bike_uids': ['46955',
#       '828262',
#       '46747',
#       '46703',
#       '46657',
#       '46642',
#       '46611',
#       '46435',
#       '829964'],
#      'virtual': False}},
#    {'id': '1e0594a2e0868d316521af81193bc19c',
#     'name': 'CoMo Pop up hub (temp)',
#     'latitude': 55.858285,
#     'longitude': -4.221215,
#     'timestamp': '2025-07-01T19:18:19.378483+00:00Z',
#     'free_bikes': 0,
#     'empty_slots': 1,
#     'extra': {'uid': '481710184',
#      'number': '8499',
#      'slots': 1,
#      'bike_uids': [],
#      'virtual': False}},
#    {'id': '27e224157e6a5dcec09cd3ad37b62315',
#     'name': 'Springfield Quay 2',
#     'latitude': 55.854391,
#     'longitude': -4.274764,
#     'timestamp': '2025-07-01T19:18:19.375340+00:00Z',
#     'free_bikes': 0,
#     'empty_slots': 6,
#     'extra': {'uid': '6269603',
#      'number': '8462',
#      'slots': 6,
#      'bike_uids': [],
#      'virtual': False}},
#    {'id': '28ae77e57c39887ceab9e2b2eb3a0e3a',
#     'name': 'University of Strathclyde (South) - ELECTRIC',
#     'latitude': 55.860633,
#     'longitude': -4.2419,
#     'timestamp': '2025-07-01T19:18:19.374325+00:00Z',
#     'free_bikes': 2,
#     'empty_slots': 10,
#     'extra': {'uid': '266170',
#      'number': '8433',
#      'slots': 12,
#      'bike_uids': ['21031', '22202'],
#      'virtual': False}},
#    {'id': '2a86fb913aad33c3e3deee02dd93f76d',
#     'name': 'Buchanan Street Bus Station - ELECTRIC',
#     'latitude': 55.864993,
#     'longitude': -4.252567,
#     'timestamp': '2025-07-01T19:18:19.375046+00:00Z',
#     'free_bikes': 2,
#     'empty_slots': 7,
#     'extra': {'uid': '380893',
#      'number': '8404',
#      'slots': 10,
#      'bike_uids': ['46721'],
#      'virtual': False}},
#    {'id': '2b7a24c5351796cdc372275308f7cfc9',
#     'name': 'Springburn Railway Station',
#     'latitude': 55.882232,
#     'longitude': -4.230428,
#     'timestamp': '2025-07-01T19:18:19.376675+00:00Z',
#     'free_bikes': 0,
#     'empty_slots': 8,
#     'extra': {'uid': '31475534',
#      'number': '8237',
#      'slots': 8,
#      'bike_uids': [],
#      'virtual': False}},
#    {'id': '2c49302c8bb3a00373f898594228a941',
#     'name': 'London Road Central',
#     'latitude': 55.847638,
#     'longitude': -4.202957,
#     'timestamp': '2025-07-01T19:18:19.377780+00:00Z',
#     'free_bikes': 4,
#     'empty_slots': 6,
#     'extra': {'uid': '213996907',
#      'number': '8474',
#      'slots': 10,
#      'bike_uids': ['46539', '46487', '46430', '828975'],
#      'virtual': False}},
#    {'id': '2cfbd10e44bf17c20e682172e1cb026d',
#     'name': 'Glasgow Kelvin College East',
#     'latitude': 55.857858,
#     'longitude': -4.203123,
#     'timestamp': '2025-07-01T19:18:19.378461+00:00Z',
#     'free_bikes': 3,
#     'empty_slots': 7,
#     'extra': {'uid': '262744830',
#      'number': '8489',
#      'slots': 10,
#      'bike_uids': ['823637', '47965', '829997'],
#      'virtual': False}},
#    {'id': '2ee7f8a8347b8ee388d6beeef94c837d',
#     'name': 'Scotstoun South',
#     'latitude': 55.875431,
#     'longitude': -4.342325,
#     'timestamp': '2025-07-01T19:18:19.377131+00:00Z',
#     'free_bikes': 5,
#     'empty_slots': 6,
#     'extra': {'uid': '105741829',
#      'number': '8311',
#      'slots': 12,
#      'bike_uids': ['47875', '840031', '823571', '46785', '828974'],
#      'virtual': False}},
#    {'id': '3860eb7809fcced150d10d78ca2a165c',
#     'name': 'University Hospital, Queen Eliza',
#     'latitude': 55.862838,
#     'longitude': -4.341885,
#     'timestamp': '2025-07-01T19:18:19.375091+00:00Z',
#     'free_bikes': 2,
#     'empty_slots': 5,
#     'extra': {'uid': '751103',
#      'number': '8450',
#      'slots': 8,
#      'bike_uids': ['46900', '46643'],
#      'virtual': False}},
#    {'id': '3870596cc1a00a724f4ed1037e103977',
#     'name': 'Pollokshaws West Railway Station',
#     'latitude': 55.824907,
#     'longitude': -4.299678,
#     'timestamp': '2025-07-01T19:18:19.377853+00:00Z',
#     'free_bikes': 0,
#     'empty_slots': 9,
#     'extra': {'uid': '262741426',
#      'number': '8481',
#      'slots': 10,
#      'bike_uids': [],
#      'virtual': False}},
#    {'id': '3c3dcd5ab1d1b41a307a4436823f798a',
#     'name': 'Kelvinhall Subway',
#     'latitude': 55.870857,
#     'longitude': -4.300665,
#     'timestamp': '2025-07-01T19:18:19.377396+00:00Z',
#     'free_bikes': 13,
#     'empty_slots': 0,
#     'extra': {'uid': '105742172',
#      'number': '8314',
#      'slots': 6,
#      'bike_uids': ['47502',
#       '825500',
#       '828910',
#       '823527',
#       '46928',
#       '46797',
#       '823608',
#       '46734',
#       '46763',
#       '46653',
#       '46459',
#       '828314',
#       '829024'],
#      'virtual': False}},
#    {'id': '3ddf8661cd54b63e042898f8c83b38e0',
#     'name': 'Glasgow Caledonian University - ELECTRIC',
#     'latitude': 55.865817,
#     'longitude': -4.251367,
#     'timestamp': '2025-07-01T19:18:19.374239+00:00Z',
#     'free_bikes': 1,
#     'empty_slots': 4,
#     'extra': {'uid': '266157',
#      'number': '8405',
#      'slots': 6,
#      'bike_uids': ['22037'],
#      'virtual': False}},
#    {'id': '3ff58e3afee22e9aeef8b1e95650e749',
#     'name': "St George's Cross - ELECTRIC",
#     'latitude': 55.871367,
#     'longitude': -4.269117,
#     'timestamp': '2025-07-01T19:18:19.373895+00:00Z',
#     'free_bikes': 4,
#     'empty_slots': 2,
#     'extra': {'uid': '264294',
#      'number': '8408',
#      'slots': 4,
#      'bike_uids': ['825564', '46687', '46506', '828134'],
#      'virtual': False}},
#    {'id': '4569cc932fe326799b99930cad84c476',
#     'name': 'Possil Health Centre (Saracen Street) - ELECTRIC',
#     'latitude': 55.881493,
#     'longitude': -4.254465,
#     'timestamp': '2025-07-01T19:18:19.375928+00:00Z',
#     'free_bikes': 4,
#     'empty_slots': 4,
#     'extra': {'uid': '19548440',
#      'number': '8414',
#      'slots': 8,
#      'bike_uids': ['828229', '823555', '825901', '829986'],
#      'virtual': False}},
#    {'id': '47a68fd067ea7f71ee08c1fbdd7c9c9b',
#     'name': 'Glasgow Science Centre',
#     'latitude': 55.8585,
#     'longitude': -4.292972,
#     'timestamp': '2025-07-01T19:18:19.376692+00:00Z',
#     'free_bikes': 3,
#     'empty_slots': 7,
#     'extra': {'uid': '41822435',
#      'number': '8426',
#      'slots': 10,
#      'bike_uids': ['823589', '829979', '829000'],
#      'virtual': False}},
#    {'id': '540d5877eb2aa25add536be07be49962',
#     'name': 'Kelvinbridge Subway - ELECTRIC',
#     'latitude': 55.87501,
#     'longitude': -4.280371,
#     'timestamp': '2025-07-01T19:18:19.374091+00:00Z',
#     'free_bikes': 2,
#     'empty_slots': 6,
#     'extra': {'uid': '264303',
#      'number': '8418',
#      'slots': 8,
#      'bike_uids': ['46700', '46666'],
#      'virtual': False}},
#    {'id': '5542f3a29121984f8bab4d281d63bedd',
#     'name': "People's Palace",
#     'latitude': 55.852086,
#     'longitude': -4.237032,
#     'timestamp': '2025-07-01T19:18:19.378437+00:00Z',
#     'free_bikes': 3,
#     'empty_slots': 7,
#     'extra': {'uid': '262744061',
#      'number': '8485',
#      'slots': 10,
#      'bike_uids': ['22785', '46495', '829292'],
#      'virtual': False}},
#    {'id': '573cb802d312c0c7388eeb86b7df2b16',
#     'name': 'Maryhill Library',
#     'latitude': 55.891127,
#     'longitude': -4.290879,
#     'timestamp': '2025-07-01T19:18:19.376851+00:00Z',
#     'free_bikes': 2,
#     'empty_slots': 6,
#     'extra': {'uid': '42613824',
#      'number': '8213',
#      'slots': 8,
#      'bike_uids': ['46786', '828308'],
#      'virtual': False}},
#    {'id': '57d53cfefc9f5e8871e9758b1f6128f8',
#     'name': 'Clifton St / Kelvingrove Park East',
#     'latitude': 55.86698,
#     'longitude': -4.278874,
#     'timestamp': '2025-07-01T19:18:19.377085+00:00Z',
#     'free_bikes': 0,
#     'empty_slots': 10,
#     'extra': {'uid': '55600478',
#      'number': '8205',
#      'slots': 10,
#      'bike_uids': [],
#      'virtual': False}},
#    {'id': '5a527c8ff4d91a318d173dbdbce298c0',
#     'name': 'Eglinton Toll - ELECTRIC',
#     'latitude': 55.843308,
#     'longitude': -4.26217,
#     'timestamp': '2025-07-01T19:18:19.374581+00:00Z',
#     'free_bikes': 3,
#     'empty_slots': 4,
#     'extra': {'uid': '349458',
#      'number': '8446',
#      'slots': 6,
#      'bike_uids': ['826826', '46448', '828155'],
#      'virtual': False}},
#    {'id': '5a611496ed54f7f74525c262367db06f',
#     'name': 'Yorkhill Street South',
#     'latitude': 55.864135,
#     'longitude': -4.292988,
#     'timestamp': '2025-07-01T19:18:19.377106+00:00Z',
#     'free_bikes': 5,
#     'empty_slots': 3,
#     'extra': {'uid': '66595311',
#      'number': '8310',
#      'slots': 8,
#      'bike_uids': ['21046', '823593', '46988', '46673', '46652'],
#      'virtual': False}},
#    {'id': '5aef9920fd2384a972eafa84aa577439',
#     'name': 'Argyle Street Railway Station - ELECTRIC',
#     'latitude': 55.857575,
#     'longitude': -4.249976,
#     'timestamp': '2025-07-01T19:18:19.374221+00:00Z',
#     'free_bikes': 0,
#     'empty_slots': 7,
#     'extra': {'uid': '264392',
#      'number': '8411',
#      'slots': 7,
#      'bike_uids': [],
#      'virtual': False}},
#    {'id': '5c9021a0e68ddd0d3e47cc90e59c77c8',
#     'name': 'Pollokshields East Railway',
#     'latitude': 55.841494,
#     'longitude': -4.269701,
#     'timestamp': '2025-07-01T19:18:19.376770+00:00Z',
#     'free_bikes': 2,
#     'empty_slots': 8,
#     'extra': {'uid': '42487653',
#      'number': '8210',
#      'slots': 10,
#      'bike_uids': ['46589', '46586'],
#      'virtual': False}},
#    {'id': '5d5e2ae1a3a0fe0075c7a9d3432e736b',
#     'name': 'Cessnock Subway Station - ELECTRIC',
#     'latitude': 55.85196,
#     'longitude': -4.294538,
#     'timestamp': '2025-07-01T19:18:19.374523+00:00Z',
#     'free_bikes': 17,
#     'empty_slots': 0,
#     'extra': {'uid': '349455',
#      'number': '8444',
#      'slots': 10,
#      'bike_uids': ['826830',
#       '826907',
#       '47890',
#       '47881',
#       '46943',
#       '46795',
#       '828982',
#       '46661',
#       '828967',
#       '46551',
#       '46500',
#       '46415',
#       '47934',
#       '828224',
#       '829999',
#       '829122',
#       '828328'],
#      'virtual': False}},
#    {'id': '6006222102c4bdaf1e119fc089393312',
#     'name': 'Port Dundas',
#     'latitude': 55.877822,
#     'longitude': -4.254817,
#     'timestamp': '2025-07-01T19:18:19.375476+00:00Z',
#     'free_bikes': 1,
#     'empty_slots': 7,
#     'extra': {'uid': '6269638',
#      'number': '8469',
#      'slots': 8,
#      'bike_uids': ['46731'],
#      'virtual': False}},
#    {'id': '6250eaa7a4d4ffac2452eb0509ccbd59',
#     'name': 'Broomhill',
#     'latitude': 55.871005,
#     'longitude': -4.321313,
#     'timestamp': '2025-07-01T19:18:19.376588+00:00Z',
#     'free_bikes': 5,
#     'empty_slots': 5,
#     'extra': {'uid': '31234355',
#      'number': '8233',
#      'slots': 12,
#      'bike_uids': ['46985', '828940', '828296', '46468', '829199'],
#      'virtual': False}},
#    {'id': '64351cf3fd58727dbb26147dec40e855',
#     'name': 'Duke Street Railway Station',
#     'latitude': 55.858222,
#     'longitude': -4.213473,
#     'timestamp': '2025-07-01T19:18:19.375256+00:00Z',
#     'free_bikes': 0,
#     'empty_slots': 8,
#     'extra': {'uid': '3812792',
#      'number': '8458',
#      'slots': 8,
#      'bike_uids': [],
#      'virtual': False}},
#    {'id': '654cfe414a7d682dfffd1259586b364f',
#     'name': 'Scottish Event Campus (formerly S.E.C.C)',
#     'latitude': 55.859081,
#     'longitude': -4.287211,
#     'timestamp': '2025-07-01T19:18:19.374020+00:00Z',
#     'free_bikes': 5,
#     'empty_slots': 3,
#     'extra': {'uid': '264300',
#      'number': '8415',
#      'slots': 8,
#      'bike_uids': ['46766', '46702', '46699', '46570', '46466'],
#      'virtual': False}},
#    {'id': '65a1fded1cfdaf39b8c7ea2cc561144b',
#     'name': 'Bellahouston Park',
#     'latitude': 55.849072,
#     'longitude': -4.314376,
#     'timestamp': '2025-07-01T19:18:19.376974+00:00Z',
#     'free_bikes': 6,
#     'empty_slots': 2,
#     'extra': {'uid': '55600054',
#      'number': '8201',
#      'slots': 8,
#      'bike_uids': ['22752', '46876', '46831', '47907', '829960', '829182'],
#      'virtual': False}},
#    {'id': '66bf0c2b0588b8c742caeb43d89a82c2',
#     'name': 'Alexandra Park (south entrance) Alexandra Parade Railway Station',
#     'latitude': 55.863128,
#     'longitude': -4.210282,
#     'timestamp': '2025-07-01T19:18:19.375239+00:00Z',
#     'free_bikes': 0,
#     'empty_slots': 7,
#     'extra': {'uid': '3812776',
#      'number': '8457',
#      'slots': 7,
#      'bike_uids': [],
#      'virtual': False}},
#    {'id': '6c5f3eaafa4323831910bb404125cef9',
#     'name': 'Glasgow Central West',
#     'latitude': 55.858587,
#     'longitude': -4.259847,
#     'timestamp': '2025-07-01T19:18:19.376243+00:00Z',
#     'free_bikes': 1,
#     'empty_slots': 7,
#     'extra': {'uid': '28521334',
#      'number': '8216',
#      'slots': 8,
#      'bike_uids': ['47268'],
#      'virtual': False}},
#    {'id': '6dd6aeaa689caacc619659b44bebb9c7',
#     'name': 'Clyde Place Quay',
#     'latitude': 55.854931,
#     'longitude': -4.260144,
#     'timestamp': '2025-07-01T19:18:19.378184+00:00Z',
#     'free_bikes': 1,
#     'empty_slots': 9,
#     'extra': {'uid': '262743248',
#      'number': '8483',
#      'slots': 10,
#      'bike_uids': ['47935'],
#      'virtual': False}},
#    {'id': '6e1c95db152793f835bd905855c13c04',
#     'name': 'Glasgow Green - Saltmarket / Clyde Place - ELECTRIC',
#     'latitude': 55.853176,
#     'longitude': -4.246661,
#     'timestamp': '2025-07-01T19:18:19.375293+00:00Z',
#     'free_bikes': 5,
#     'empty_slots': 7,
#     'extra': {'uid': '3812886',
#      'number': '8460',
#      'slots': 8,
#      'bike_uids': ['825594', '46792', '46674', '46602', '46492'],
#      'virtual': False}},
#    {'id': '6f47ac14f7aaa6b2c04936f30a5c2bb6',
#     'name': 'University of Glasgow (East) - ELECTRIC',
#     'latitude': 55.871763,
#     'longitude': -4.27807,
#     'timestamp': '2025-07-01T19:18:19.374347+00:00Z',
#     'free_bikes': 2,
#     'empty_slots': 6,
#     'extra': {'uid': '266171',
#      'number': '8435',
#      'slots': 5,
#      'bike_uids': ['828219', '46927'],
#      'virtual': False}},
#    {'id': '70c80c14fe5f7f1049a85e33856137ec',
#     'name': 'Trongate',
#     'latitude': 55.855961,
#     'longitude': -4.244671,
#     'timestamp': '2025-07-01T19:18:19.374306+00:00Z',
#     'free_bikes': 1,
#     'empty_slots': 4,
#     'extra': {'uid': '266169',
#      'number': '8431',
#      'slots': 5,
#      'bike_uids': ['828141'],
#      'virtual': False}},
#    {'id': '71b02b6f26f03e58c97dec1e1c9faa00',
#     'name': 'Botanic Gardens - ELECTRIC',
#     'latitude': 55.878278,
#     'longitude': -4.288487,
#     'timestamp': '2025-07-01T19:18:19.374068+00:00Z',
#     'free_bikes': 4,
#     'empty_slots': 4,
#     'extra': {'uid': '264302',
#      'number': '8417',
#      'slots': 8,
#      'bike_uids': ['825886', '46913', '46828', '46613'],
#      'virtual': False}},
#    {'id': '7245bbeaa7a5357af921174d7ae855d4',
#     'name': 'Broomielaw - ELECTRIC',
#     'latitude': 55.8566,
#     'longitude': -4.263521,
#     'timestamp': '2025-07-01T19:18:19.373997+00:00Z',
#     'free_bikes': 2,
#     'empty_slots': 11,
#     'extra': {'uid': '264299',
#      'number': '8413',
#      'slots': 16,
#      'bike_uids': ['46446', '828120'],
#      'virtual': False}},
#    {'id': '7ad6b0b3be3cb3d85e687bdf53358611',
#     'name': 'The Round Toll',
#     'latitude': 55.87422,
#     'longitude': -4.26136,
#     'timestamp': '2025-07-01T19:18:19.376411+00:00Z',
#     'free_bikes': 1,
#     'empty_slots': 7,
#     'extra': {'uid': '28521431',
#      'number': '8218',
#      'slots': 8,
#      'bike_uids': ['826832'],
#      'virtual': False}},
#    {'id': '7ae43e2d5ec8ea21445422bd2dcfcb2b',
#     'name': 'Govan Cross',
#     'latitude': 55.862606,
#     'longitude': -4.311125,
#     'timestamp': '2025-07-01T19:18:19.374553+00:00Z',
#     'free_bikes': 7,
#     'empty_slots': 0,
#     'extra': {'uid': '349456',
#      'number': '8445',
#      'slots': 8,
#      'bike_uids': ['38932',
#       '829308',
#       '825646',
#       '46981',
#       '46963',
#       '828192',
#       '828987'],
#      'virtual': False}},
#    {'id': '7f57f6deed054209b94f5d22e1bb5b68',
#     'name': 'Firhill Road - ELECTRIC',
#     'latitude': 55.878787,
#     'longitude': -4.26877,
#     'timestamp': '2025-07-01T19:18:19.375499+00:00Z',
#     'free_bikes': 4,
#     'empty_slots': 2,
#     'extra': {'uid': '6270126',
#      'number': '8464',
#      'slots': 7,
#      'bike_uids': ['823534', '823504', '46515', '829289'],
#      'virtual': False}},
#    {'id': '7fd473d65bb4ead7217d778a38d56dc2',
#     'name': 'Mount Vernon Railway Station',
#     'latitude': 55.840336,
#     'longitude': -4.135251,
#     'timestamp': '2025-07-01T19:18:19.376792+00:00Z',
#     'free_bikes': 3,
#     'empty_slots': 5,
#     'extra': {'uid': '42553766',
#      'number': '8211',
#      'slots': 8,
#      'bike_uids': ['46834', '828249', '829148'],
#      'virtual': False}},
#    {'id': '7fde42277f0af769fa2844ac44fb18bb',
#     'name': 'Cathcart Railway Station',
#     'latitude': 55.817338,
#     'longitude': -4.262688,
#     'timestamp': '2025-07-01T19:18:19.376720+00:00Z',
#     'free_bikes': 5,
#     'empty_slots': 7,
#     'extra': {'uid': '42417389',
#      'number': '8206',
#      'slots': 12,
#      'bike_uids': ['46732', '46638', '829970', '829957', '829086'],
#      'virtual': False}},
#    {'id': '80c191c76711807560f1dee0ec98b9c4',
#     'name': 'Langside Hall - ELECTRIC',
#     'latitude': 55.831951,
#     'longitude': -4.277989,
#     'timestamp': '2025-07-01T19:18:19.375173+00:00Z',
#     'free_bikes': 2,
#     'empty_slots': 4,
#     'extra': {'uid': '3812694',
#      'number': '8454',
#      'slots': 4,
#      'bike_uids': ['47833', '829161'],
#      'virtual': False}},
#    {'id': '8486f63f1088194889096079329cdbdb',
#     'name': 'Shawlands Railway Station - ELECTRIC',
#     'latitude': 55.827371,
#     'longitude': -4.29567,
#     'timestamp': '2025-07-01T19:18:19.375194+00:00Z',
#     'free_bikes': 3,
#     'empty_slots': 5,
#     'extra': {'uid': '3812713',
#      'number': '8455',
#      'slots': 8,
#      'bike_uids': ['82390', '46567', '46514'],
#      'virtual': False}},
#    {'id': '85c3b5be1873561dc445f46324d143b7',
#     'name': 'St Enoch Square - ELECTRIC',
#     'latitude': 55.856859,
#     'longitude': -4.255593,
#     'timestamp': '2025-07-01T19:18:19.373921+00:00Z',
#     'free_bikes': 2,
#     'empty_slots': 8,
#     'extra': {'uid': '264295',
#      'number': '8410',
#      'slots': 12,
#      'bike_uids': ['38718', '47947'],
#      'virtual': False}},
#    {'id': '8af6d6e52a43dc3df9086e10ab9da2a1',
#     'name': 'Waterloo Street - ELECTRIC',
#     'latitude': 55.86077,
#     'longitude': -4.264535,
#     'timestamp': '2025-07-01T19:18:19.373794+00:00Z',
#     'free_bikes': 3,
#     'empty_slots': 9,
#     'extra': {'uid': '264283',
#      'number': '8402',
#      'slots': 12,
#      'bike_uids': ['828265', '828954', '46510'],
#      'virtual': False}},
#    {'id': '90ca952e355fd4673ea26061d13d8841',
#     'name': 'Anniesland Library',
#     'latitude': 55.890398,
#     'longitude': -4.324766,
#     'timestamp': '2025-07-01T19:18:19.376881+00:00Z',
#     'free_bikes': 3,
#     'empty_slots': 5,
#     'extra': {'uid': '42613965',
#      'number': '8214',
#      'slots': 8,
#      'bike_uids': ['823631', '46636', '46498'],
#      'virtual': False}},
#    {'id': '90f4aed9eeacf63d2f1a9af8ba77d5bc',
#     'name': 'Battlefield - ELECTRIC',
#     'latitude': 55.827395,
#     'longitude': -4.265319,
#     'timestamp': '2025-07-01T19:18:19.375405+00:00Z',
#     'free_bikes': 7,
#     'empty_slots': 3,
#     'extra': {'uid': '6269629',
#      'number': '8466',
#      'slots': 10,
#      'bike_uids': ['826777',
#       '82346',
#       '46548',
#       '46502',
#       '46455',
#       '47920',
#       '47958'],
#      'virtual': False}},
#    {'id': '94bb26490e1ac10b92057d2136aaec12',
#     'name': 'Stobhill Hospital',
#     'latitude': 55.890389,
#     'longitude': -4.216525,
#     'timestamp': '2025-07-01T19:18:19.377370+00:00Z',
#     'free_bikes': 2,
#     'empty_slots': 9,
#     'extra': {'uid': '105742063',
#      'number': '8313',
#      'slots': 11,
#      'bike_uids': ['47852', '46531'],
#      'virtual': False}},
#    {'id': '982a00e7910b5eaae622461281c86b53',
#     'name': 'Dalmarnock Railway Station - ELECTRIC',
#     'latitude': 55.842561,
#     'longitude': -4.217704,
#     'timestamp': '2025-07-01T19:18:19.375216+00:00Z',
#     'free_bikes': 8,
#     'empty_slots': 1,
#     'extra': {'uid': '3812770',
#      'number': '8456',
#      'slots': 8,
#      'bike_uids': ['840033',
#       '840023',
#       '828205',
#       '46740',
#       '46660',
#       '828212',
#       '46483',
#       '828222'],
#      'virtual': False}},
#    {'id': '9b7e254f4f98c7ab070e5a9958d420ef',
#     'name': 'Glasgow Forge (Gallowgate)',
#     'latitude': 55.852705,
#     'longitude': -4.201594,
#     'timestamp': '2025-07-01T19:18:19.375979+00:00Z',
#     'free_bikes': 3,
#     'empty_slots': 5,
#     'extra': {'uid': '19548760',
#      'number': '8436',
#      'slots': 8,
#      'bike_uids': ['47611', '46844', '46408'],
#      'virtual': False}},
#    {'id': 'a087989280fd941fd9c41c3e787940ae',
#     'name': 'University of Strathclyde (North)',
#     'latitude': 55.862983,
#     'longitude': -4.241,
#     'timestamp': '2025-07-01T19:18:19.374179+00:00Z',
#     'free_bikes': 3,
#     'empty_slots': 0,
#     'extra': {'uid': '264309',
#      'number': '8424',
#      'slots': 3,
#      'bike_uids': ['46894', '46425', '47931'],
#      'virtual': False}},
#    {'id': 'a1829c3fd840369355ada2949567d15a',
#     'name': 'Central Station - ELECTRIC',
#     'latitude': 55.860776,
#     'longitude': -4.258597,
#     'timestamp': '2025-07-01T19:18:19.375711+00:00Z',
#     'free_bikes': 3,
#     'empty_slots': 8,
#     'extra': {'uid': '19164571',
#      'number': '8401',
#      'slots': 14,
#      'bike_uids': ['46754', '46644', '46609'],
#      'virtual': False}},
#    {'id': 'a19e9249f64251a331f70f78845241c9',
#     'name': 'Queen Margaret Drive / Maryhill Road',
#     'latitude': 55.8849,
#     'longitude': -4.281414,
#     'timestamp': '2025-07-01T19:18:19.374045+00:00Z',
#     'free_bikes': 3,
#     'empty_slots': 5,
#     'extra': {'uid': '264301',
#      'number': '8419',
#      'slots': 8,
#      'bike_uids': ['47540', '46560', '829293'],
#      'virtual': False}},
#    {'id': 'a5fe191b595724ce2fa7372b3ccca653',
#     'name': 'Kelvingrove Art Gallery - ELECTRIC',
#     'latitude': 55.868352,
#     'longitude': -4.289405,
#     'timestamp': '2025-07-01T19:18:19.374113+00:00Z',
#     'free_bikes': 3,
#     'empty_slots': 5,
#     'extra': {'uid': '264304',
#      'number': '8420',
#      'slots': 10,
#      'bike_uids': ['828225', '823596', '829969'],
#      'virtual': False}},
#    {'id': 'a8db8c24388d5d0ce7143678dfa0e676',
#     'name': 'Gorbals Library',
#     'latitude': 55.848564,
#     'longitude': -4.250996,
#     'timestamp': '2025-07-01T19:18:19.376907+00:00Z',
#     'free_bikes': 1,
#     'empty_slots': 7,
#     'extra': {'uid': '42614033',
#      'number': '8215',
#      'slots': 8,
#      'bike_uids': ['826610'],
#      'virtual': False}},
#    {'id': 'a9d5888ec8ab5a638fbe933e0a5311de',
#     'name': 'Queens Park West',
#     'latitude': 55.835042,
#     'longitude': -4.272346,
#     'timestamp': '2025-07-01T19:18:19.375021+00:00Z',
#     'free_bikes': 2,
#     'empty_slots': 6,
#     'extra': {'uid': '349461',
#      'number': '8448',
#      'slots': 8,
#      'bike_uids': ['828201', '46802'],
#      'virtual': False}},
#    {'id': 'aa439d2a415edfcb198febf8bf3cd7a7',
#     'name': 'St Andrews Drive - Dalziel Drive',
#     'latitude': 55.840988,
#     'longitude': -4.289947,
#     'timestamp': '2025-07-01T19:18:19.377427+00:00Z',
#     'free_bikes': 1,
#     'empty_slots': 5,
#     'extra': {'uid': '105742240',
#      'number': '8315',
#      'slots': 6,
#      'bike_uids': ['823584'],
#      'virtual': False}},
#    {'id': 'aaaa2f4104d5aac71e81537d91745779',
#     'name': 'Blythswood Square',
#     'latitude': 55.863885,
#     'longitude': -4.263682,
#     'timestamp': '2025-07-01T19:18:19.378408+00:00Z',
#     'free_bikes': 4,
#     'empty_slots': 4,
#     'extra': {'uid': '262743571',
#      'number': '8484',
#      'slots': 8,
#      'bike_uids': ['12014', '22839', '46619', '829981'],
#      'virtual': False}},
#    {'id': 'ab5e5dc12c8217d4077ba0df3970feb5',
#     'name': 'Glasgow Green',
#     'latitude': 55.84945,
#     'longitude': -4.23375,
#     'timestamp': '2025-07-01T19:18:19.373971+00:00Z',
#     'free_bikes': 11,
#     'empty_slots': 1,
#     'extra': {'uid': '264298',
#      'number': '8412',
#      'slots': 12,
#      'bike_uids': ['82396',
#       '825569',
#       '825650',
#       '828939',
#       '46952',
#       '46884',
#       '46817',
#       '46647',
#       '46634',
#       '47964',
#       '829171'],
#      'virtual': False}},
#    {'id': 'abb478d282fc4352a662a4fb1308a544',
#     'name': 'Woodside (North) - ELECTRIC',
#     'latitude': 55.875061,
#     'longitude': -4.270678,
#     'timestamp': '2025-07-01T19:18:19.375375+00:00Z',
#     'free_bikes': 9,
#     'empty_slots': 2,
#     'extra': {'uid': '6269626',
#      'number': '8465',
#      'slots': 8,
#      'bike_uids': ['47237',
#       '47898',
#       '828973',
#       '828211',
#       '46627',
#       '46526',
#       '46474',
#       '829951',
#       '47768'],
#      'virtual': False}},
#    {'id': 'abb4b8f19b7371a31a1773ddf19dac8c',
#     'name': 'Springfield Rd',
#     'latitude': 55.848885,
#     'longitude': -4.20064,
#     'timestamp': '2025-07-01T19:18:19.377052+00:00Z',
#     'free_bikes': 4,
#     'empty_slots': 2,
#     'extra': {'uid': '55600387',
#      'number': '8204',
#      'slots': 6,
#      'bike_uids': ['828306', '46645', '829978', '828123'],
#      'virtual': False}},
#    {'id': 'ad008187b01147da4b6986fec9f25495',
#     'name': 'Bath Street',
#     'latitude': 55.864132,
#     'longitude': -4.259101,
#     'timestamp': '2025-07-01T19:18:19.376522+00:00Z',
#     'free_bikes': 0,
#     'empty_slots': 8,
#     'extra': {'uid': '28521513',
#      'number': '8219',
#      'slots': 8,
#      'bike_uids': [],
#      'virtual': False}},
#    {'id': 'af1d0f25cbc75377878349fde4d86133',
#     'name': 'Merchant Square - ELECTRIC',
#     'latitude': 55.858167,
#     'longitude': -4.245483,
#     'timestamp': '2025-07-01T19:18:19.373867+00:00Z',
#     'free_bikes': 1,
#     'empty_slots': 7,
#     'extra': {'uid': '264293',
#      'number': '8407',
#      'slots': 8,
#      'bike_uids': ['46709'],
#      'virtual': False}},
#    {'id': 'af89fc71d4e9b25fd63a7ae8861f4c03',
#     'name': 'Hampden Park and Ride',
#     'latitude': 55.827974,
#     'longitude': -4.247278,
#     'timestamp': '2025-07-01T19:18:19.377450+00:00Z',
#     'free_bikes': 8,
#     'empty_slots': 0,
#     'extra': {'uid': '105742309',
#      'number': '8316',
#      'slots': 4,
#      'bike_uids': ['828209',
#       '828275',
#       '825893',
#       '46893',
#       '46840',
#       '828985',
#       '46727',
#       '46667'],
#      'virtual': False}},
#    {'id': 'b205037f7c8a72a7acf2af890570bb16',
#     'name': 'Riddrie South',
#     'latitude': 55.867405,
#     'longitude': -4.192788,
#     'timestamp': '2025-07-01T19:18:19.376816+00:00Z',
#     'free_bikes': 3,
#     'empty_slots': 4,
#     'extra': {'uid': '42613734',
#      'number': '8212',
#      'slots': 8,
#      'bike_uids': ['47906', '47915', '829156'],
#      'virtual': False}},
#    {'id': 'b60e67062c32d2147f8892de3a446610',
#     'name': 'Anderston West',
#     'latitude': 55.861585,
#     'longitude': -4.274518,
#     'timestamp': '2025-07-01T19:18:19.377637+00:00Z',
#     'free_bikes': 1,
#     'empty_slots': 7,
#     'extra': {'uid': '150125330',
#      'number': '8472',
#      'slots': 8,
#      'bike_uids': ['46975'],
#      'virtual': False}},
#    {'id': 'b98603df18dece74e168037c3fe67a2c',
#     'name': 'Sauchiehall Street',
#     'latitude': 55.865291,
#     'longitude': -4.261756,
#     'timestamp': '2025-07-01T19:18:19.375358+00:00Z',
#     'free_bikes': 0,
#     'empty_slots': 7,
#     'extra': {'uid': '6269618',
#      'number': '8463',
#      'slots': 7,
#      'bike_uids': [],
#      'virtual': False}},
#    {'id': 'ba4133ab0ad5c5b405a541c5dfa5814f',
#     'name': 'Finnieston Street',
#     'latitude': 55.863422,
#     'longitude': -4.280677,
#     'timestamp': '2025-07-01T19:18:19.374391+00:00Z',
#     'free_bikes': 6,
#     'empty_slots': 2,
#     'extra': {'uid': '315912',
#      'number': '8438',
#      'slots': 8,
#      'bike_uids': ['828280', '823561', '828961', '46618', '46569', '46462'],
#      'virtual': False}},
#    {'id': 'ba6d3b1c4cafd1b3e29f950f613c4605',
#     'name': 'Queens Park Railway Station - ELECTRIC',
#     'latitude': 55.834976,
#     'longitude': -4.265485,
#     'timestamp': '2025-07-01T19:18:19.374985+00:00Z',
#     'free_bikes': 2,
#     'empty_slots': 7,
#     'extra': {'uid': '349460',
#      'number': '8447',
#      'slots': 8,
#      'bike_uids': ['826879', '46716'],
#      'virtual': False}},
#    {'id': 'bc208a63ac25b883b9eb6e28bfff2f28',
#     'name': 'Shakespeare Street (Maryhill) - ELECTRIC',
#     'latitude': 55.886934,
#     'longitude': -4.285022,
#     'timestamp': '2025-07-01T19:18:19.375905+00:00Z',
#     'free_bikes': 0,
#     'empty_slots': 4,
#     'extra': {'uid': '19548002',
#      'number': '8427',
#      'slots': 4,
#      'bike_uids': [],
#      'virtual': False}},
#    {'id': 'bfdb33b93e6a6a80f01c46a8284203e0',
#     'name': 'George Square - ELECTRIC',
#     'latitude': 55.86155,
#     'longitude': -4.2494,
#     'timestamp': '2025-07-01T19:18:19.373843+00:00Z',
#     'free_bikes': 0,
#     'empty_slots': 10,
#     'extra': {'uid': '264292',
#      'number': '8406',
#      'slots': 10,
#      'bike_uids': [],
#      'virtual': False}},
#    {'id': 'c04c3fc64f0ba6c420bd3184f474bfc9',
#     'name': 'University of Glasgow (West)',
#     'latitude': 55.872774,
#     'longitude': -4.292135,
#     'timestamp': '2025-07-01T19:18:19.374136+00:00Z',
#     'free_bikes': 1,
#     'empty_slots': 7,
#     'extra': {'uid': '264306',
#      'number': '8422',
#      'slots': 8,
#      'bike_uids': ['829149'],
#      'virtual': False}},
#    {'id': 'c5fd8640b5ba2ad276663dac367fa293',
#     'name': 'Mount Florida Railway Station',
#     'latitude': 55.827282,
#     'longitude': -4.259255,
#     'timestamp': '2025-07-01T19:18:19.375432+00:00Z',
#     'free_bikes': 7,
#     'empty_slots': 3,
#     'extra': {'uid': '6269636',
#      'number': '8467',
#      'slots': 4,
#      'bike_uids': ['826799',
#       '46904',
#       '46862',
#       '46764',
#       '46746',
#       '46593',
#       '829247'],
#      'virtual': False}},
#    {'id': 'c7102adc0e91f9d347ac0e230471e8bc',
#     'name': 'Carrick Quay',
#     'latitude': 55.85476,
#     'longitude': -4.25164,
#     'timestamp': '2025-07-01T19:18:19.376481+00:00Z',
#     'free_bikes': 2,
#     'empty_slots': 6,
#     'extra': {'uid': '28521474',
#      'number': '8231',
#      'slots': 8,
#      'bike_uids': ['22822', '46420'],
#      'virtual': False}},
#    {'id': 'c8234c56f76f3f84d81c54ceedbdab54',
#     'name': 'Anderston Railway Station',
#     'latitude': 55.859996,
#     'longitude': -4.270163,
#     'timestamp': '2025-07-01T19:18:19.377348+00:00Z',
#     'free_bikes': 2,
#     'empty_slots': 4,
#     'extra': {'uid': '105741985',
#      'number': '8312',
#      'slots': 6,
#      'bike_uids': ['47873', '46771'],
#      'virtual': False}},
#    {'id': 'caf64729d7f752ab99f5a2c600a089c6',
#     'name': 'St Andrews Drive @ Maxwell Drive',
#     'latitude': 55.845518,
#     'longitude': -4.286476,
#     'timestamp': '2025-07-01T19:18:19.376617+00:00Z',
#     'free_bikes': 5,
#     'empty_slots': 3,
#     'extra': {'uid': '31234411',
#      'number': '8235',
#      'slots': 8,
#      'bike_uids': ['46806', '828903', '46648', '829205', '829124'],
#      'virtual': False}},
#    {'id': 'd1cfef68e6b380467d3f8927379319b3',
#     'name': 'Glasgow Cathedral - ELECTRIC',
#     'latitude': 55.862973,
#     'longitude': -4.237745,
#     'timestamp': '2025-07-01T19:18:19.373946+00:00Z',
#     'free_bikes': 5,
#     'empty_slots': 1,
#     'extra': {'uid': '264296',
#      'number': '8409',
#      'slots': 6,
#      'bike_uids': ['829317', '826626', '825559', '828236', '829993'],
#      'virtual': False}},
#    {'id': 'd204cd406e1b7af53252157f13d4df60',
#     'name': 'Burrell Collection',
#     'latitude': 55.829914,
#     'longitude': -4.306877,
#     'timestamp': '2025-07-01T19:18:19.376996+00:00Z',
#     'free_bikes': 6,
#     'empty_slots': 0,
#     'extra': {'uid': '55600156',
#      'number': '8202',
#      'slots': 6,
#      'bike_uids': ['828995', '46922', '823634', '46407', '829987', '829100'],
#      'virtual': False}},
#    {'id': 'd33c72793e492060711833bcbbd2667e',
#     'name': 'King Street South',
#     'latitude': 55.85586,
#     'longitude': -4.24695,
#     'timestamp': '2025-07-01T19:18:19.376543+00:00Z',
#     'free_bikes': 2,
#     'empty_slots': 6,
#     'extra': {'uid': '28521547',
#      'number': '8230',
#      'slots': 8,
#      'bike_uids': ['46735', '828132'],
#      'virtual': False}},
#    {'id': 'd609f2455b3dbc528814c140c6d86413',
#     'name': 'Gartnavel General Hospital',
#     'latitude': 55.883971,
#     'longitude': -4.31046,
#     'timestamp': '2025-07-01T19:18:19.375069+00:00Z',
#     'free_bikes': 5,
#     'empty_slots': 1,
#     'extra': {'uid': '733236',
#      'number': '8449',
#      'slots': 6,
#      'bike_uids': ['828273', '46911', '46812', '46545', '46497'],
#      'virtual': False}},
#    {'id': 'd80f772bb69ca8c783940446811dda56',
#     'name': 'Kelvinhaugh Street / Argyle Street - ELECTRIC',
#     'latitude': 55.865222,
#     'longitude': -4.286127,
#     'timestamp': '2025-07-01T19:18:19.375132+00:00Z',
#     'free_bikes': 1,
#     'empty_slots': 4,
#     'extra': {'uid': '3812438',
#      'number': '8451',
#      'slots': 8,
#      'bike_uids': ['46633'],
#      'virtual': False}},
#    {'id': 'd9eacbf78518d186400386d90f0cf49c',
#     'name': 'Broomhill Cross',
#     'latitude': 55.875865,
#     'longitude': -4.319601,
#     'timestamp': '2025-07-01T19:18:19.377805+00:00Z',
#     'free_bikes': 0,
#     'empty_slots': 10,
#     'extra': {'uid': '213997157',
#      'number': '8480',
#      'slots': 10,
#      'bike_uids': [],
#      'virtual': False}},
#    {'id': 'dd9ad2381ac6eb2e2826d3d8104297ec',
#     'name': 'Queen Street Railway ',
#     'latitude': 55.862102,
#     'longitude': -4.252307,
#     'timestamp': '2025-07-01T19:18:19.376928+00:00Z',
#     'free_bikes': 2,
#     'empty_slots': 8,
#     'extra': {'uid': '45172531',
#      'number': '8740',
#      'slots': 10,
#      'bike_uids': ['47148', '46556'],
#      'virtual': False}},
#    {'id': 'e1d3e09da4969404a689700ed36b5d56',
#     'name': 'Partick Interchange ',
#     'latitude': 55.869707,
#     'longitude': -4.308459,
#     'timestamp': '2025-07-01T19:18:19.374368+00:00Z',
#     'free_bikes': 5,
#     'empty_slots': 3,
#     'extra': {'uid': '266218',
#      'number': '8423',
#      'slots': 8,
#      'bike_uids': ['47022', '828955', '828933', '46940', '829241'],
#      'virtual': False}},
#    {'id': 'e6e70fe059c3461f05eff24ccab6c09d',
#     'name': 'Ibrox',
#     'latitude': 55.850987,
#     'longitude': -4.301448,
#     'timestamp': '2025-07-01T19:18:19.376220+00:00Z',
#     'free_bikes': 6,
#     'empty_slots': 2,
#     'extra': {'uid': '21603723',
#      'number': '8452',
#      'slots': 8,
#      'bike_uids': ['46998', '828234', '828976', '46755', '828983', '828087'],
#      'virtual': False}},
#    {'id': 'e7b590304d2ae958110e34961830ce68',
#     'name': 'Maryland Drive',
#     'latitude': 55.846552,
#     'longitude': -4.332797,
#     'timestamp': '2025-07-01T19:18:19.377498+00:00Z',
#     'free_bikes': 2,
#     'empty_slots': 8,
#     'extra': {'uid': '115737132',
#      'number': '8209',
#      'slots': 10,
#      'bike_uids': ['46865', '829288'],
#      'virtual': False}},
#    {'id': 'e828a82c55b279cd1e7f5f9997d86d4b',
#     'name': 'Gallery of Modern Art - ELECTRIC',
#     'latitude': 55.859716,
#     'longitude': -4.251945,
#     'timestamp': '2025-07-01T19:18:19.374285+00:00Z',
#     'free_bikes': 2,
#     'empty_slots': 10,
#     'extra': {'uid': '266168',
#      'number': '8430',
#      'slots': 12,
#      'bike_uids': ['826997', '829095'],
#      'virtual': False}},
#    {'id': 'e90cf64c1ad4360e9827143bd9234ef8',
#     'name': 'Springfield Quay 1',
#     'latitude': 55.855185,
#     'longitude': -4.273478,
#     'timestamp': '2025-07-01T19:18:19.375316+00:00Z',
#     'free_bikes': 7,
#     'empty_slots': 0,
#     'extra': {'uid': '6269590',
#      'number': '8461',
#      'slots': 6,
#      'bike_uids': ['81167',
#       '82453',
#       '46698',
#       '46603',
#       '46527',
#       '46499',
#       '46429'],
#      'virtual': False}},
#    {'id': 'e9411faefce1d3a87601ad2dae1d1efc',
#     'name': 'Hyndland Road ',
#     'latitude': 55.876975,
#     'longitude': -4.306222,
#     'timestamp': '2025-07-01T19:18:19.376571+00:00Z',
#     'free_bikes': 0,
#     'empty_slots': 8,
#     'extra': {'uid': '31234332',
#      'number': '8232',
#      'slots': 8,
#      'bike_uids': [],
#      'virtual': False}},
#    {'id': 'eb47a36e3d5fe5bc456397413bd2aa75',
#     'name': 'Bridge Street Subway - ELECTRIC',
#     'latitude': 55.8525,
#     'longitude': -4.25885,
#     'timestamp': '2025-07-01T19:18:19.374199+00:00Z',
#     'free_bikes': 2,
#     'empty_slots': 3,
#     'extra': {'uid': '264316',
#      'number': '8432',
#      'slots': 5,
#      'bike_uids': ['46948', '829194'],
#      'virtual': False}},
#    {'id': 'ec3d6eba43f27b84b35067a84fbc00c9',
#     'name': 'Barrowlands - ELECTRIC',
#     'latitude': 55.855152,
#     'longitude': -4.235294,
#     'timestamp': '2025-07-01T19:18:19.374434+00:00Z',
#     'free_bikes': 6,
#     'empty_slots': 3,
#     'extra': {'uid': '349451',
#      'number': '8440',
#      'slots': 10,
#      'bike_uids': ['47895', '828295', '823550', '46695', '46639', '829316'],
#      'virtual': False}},
#    {'id': 'ed8440d874a0b4205ddbcc0bc56f3d49',
#     'name': 'Emirates Arena',
#     'latitude': 55.846362,
#     'longitude': -4.208322,
#     'timestamp': '2025-07-01T19:18:19.374261+00:00Z',
#     'free_bikes': 6,
#     'empty_slots': 6,
#     'extra': {'uid': '266166',
#      'number': '8428',
#      'slots': 12,
#      'bike_uids': ['47518', '823505', '828220', '46772', '46424', '829950'],
#      'virtual': False}},
#    {'id': 'ef89ae581497a99c0a1d61db38e53380',
#     'name': 'Paisley Road Toll - ELECTRIC ',
#     'latitude': 55.85378,
#     'longitude': -4.279158,
#     'timestamp': '2025-07-01T19:18:19.374501+00:00Z',
#     'free_bikes': 3,
#     'empty_slots': 7,
#     'extra': {'uid': '349454',
#      'number': '8443',
#      'slots': 10,
#      'bike_uids': ['46912', '46848', '46406'],
#      'virtual': False}},
#    {'id': 'f3ad8b8957d8be86ce18b8c9a43f02e1',
#     'name': 'Bellgrove Railway Station (North) - ELECTRIC ',
#     'latitude': 55.858123,
#     'longitude': -4.224511,
#     'timestamp': '2025-07-01T19:18:19.374412+00:00Z',
#     'free_bikes': 9,
#     'empty_slots': 1,
#     'extra': {'uid': '349450',
#      'number': '8439',
#      'slots': 6,
#      'bike_uids': ['83604',
#       '829273',
#       '828972',
#       '46654',
#       '46419',
#       '46413',
#       '47928',
#       '47978',
#       '47977'],
#      'virtual': False}},
#    {'id': 'f5ac5a0223f0c88e225aa7c4d63d55f5',
#     'name': 'Broomielaw West ',
#     'latitude': 55.85658,
#     'longitude': -4.26887,
#     'timestamp': '2025-07-01T19:18:19.376377+00:00Z',
#     'free_bikes': 0,
#     'empty_slots': 8,
#     'extra': {'uid': '28521383',
#      'number': '8217',
#      'slots': 8,
#      'bike_uids': [],
#      'virtual': False}},
#    {'id': 'f6210447e1724487afe0ce63b011aecd',
#     'name': 'Knightswood Park',
#     'latitude': 55.895974,
#     'longitude': -4.354877,
#     'timestamp': '2025-07-01T19:18:19.377717+00:00Z',
#     'free_bikes': 3,
#     'empty_slots': 7,
#     'extra': {'uid': '213996668',
#      'number': '8473',
#      'slots': 10,
#      'bike_uids': ['46762', '829963', '829080'],
#      'virtual': False}},
#    {'id': 'f66dbb6e5176c4419ad1be87ea0c300d',
#     'name': 'Speirs Wharf - ELECTRIC',
#     'latitude': 55.870992,
#     'longitude': -4.260426,
#     'timestamp': '2025-07-01T19:18:19.375272+00:00Z',
#     'free_bikes': 1,
#     'empty_slots': 5,
#     'extra': {'uid': '3812875',
#      'number': '8459',
#      'slots': 7,
#      'bike_uids': ['829270'],
#      'virtual': False}},
#    {'id': 'f6b64fd82fe6e607f1fc788ace31c3a1',
#     'name': 'Fullarton',
#     'latitude': 55.837175,
#     'longitude': -4.170209,
#     'timestamp': '2025-07-01T19:18:19.377474+00:00Z',
#     'free_bikes': 3,
#     'empty_slots': 9,
#     'extra': {'uid': '114446999',
#      'number': '8234',
#      'slots': 12,
#      'bike_uids': ['47334', '828994', '46917'],
#      'virtual': False}},
#    {'id': 'f806566ccd2263bd5dbb624cdd0fb7f3',
#     'name': 'Bridgeton',
#     'latitude': 55.848939,
#     'longitude': -4.226823,
#     'timestamp': '2025-07-01T19:18:19.374456+00:00Z',
#     'free_bikes': 7,
#     'empty_slots': 1,
#     'extra': {'uid': '349452',
#      'number': '8441',
#      'slots': 8,
#      'bike_uids': ['47498',
#       '826837',
#       '46934',
#       '46724',
#       '46676',
#       '46566',
#       '46454'],
#      'virtual': False}},
#    {'id': 'f93ab2c803d81c14f7e2f1765911de04',
#     'name': 'Charing Cross Railway Station',
#     'latitude': 55.864563,
#     'longitude': -4.270055,
#     'timestamp': '2025-07-01T19:18:19.375111+00:00Z',
#     'free_bikes': 2,
#     'empty_slots': 6,
#     'extra': {'uid': '3456076',
#      'number': '8421',
#      'slots': 8,
#      'bike_uids': ['46669', '46470'],
#      'virtual': False}},
#    {'id': 'fa6bc682e8627d66891c2b6250c81b1e',
#     'name': 'Mitchell Library',
#     'latitude': 55.864788,
#     'longitude': -4.271852,
#     'timestamp': '2025-07-01T19:18:19.374157+00:00Z',
#     'free_bikes': 4,
#     'empty_slots': 2,
#     'extra': {'uid': '264308',
#      'number': '8425',
#      'slots': 6,
#      'bike_uids': ['47634', '828248', '46535', '46508'],
#      'virtual': False}},
#    {'id': 'faf9e8803c8d80741d74f98cb9ba8337',
#     'name': 'Cambridge Street - ELECTRIC',
#     'latitude': 55.865063,
#     'longitude': -4.260291,
#     'timestamp': '2025-07-01T19:18:19.375956+00:00Z',
#     'free_bikes': 2,
#     'empty_slots': 6,
#     'extra': {'uid': '19548484',
#      'number': '8434',
#      'slots': 7,
#      'bike_uids': ['828970', '46440'],
#      'virtual': False}}]}}

# %% [markdown]
# Parse through the response to get the details you want for the bike stations in that city (latitude, longitude, number of bikes).

# %%
# Extract station data 
stations = json_data['network']['stations']

# %% [markdown]
# Put your parsed results into a DataFrame.

# %%
# Convert to a pandas DataFrame
df = pd.json_normalize(stations)

# Display the first few rows of the DataFrame
df.head()
# Out:
#                                  id  \
# 0  066c99293af108ece27d9b0436c30cc4
# 1  0a106cbc148d5a0c2535b51c1dbe3b4d
# 2  0cc8c09950e1435ee7782478ed292fef
# 3  0e94d2ad012bff0cf23497963ff5fd77
# 4  101c6cd7749f373507e9444f5222b7f2
#
#                                           name   latitude  longitude  \
# 0                             Riverside Museum  55.865683  -4.305367
# 1                                     Parkhead  55.846524  -4.197475
# 2      Tollcross International Swimming Centre  55.844250  -4.176167
# 3                                 Shields Road  55.845807  -4.275232
# 4  Shawlands Shopping Centre (Kilmarnock Road)  55.829057  -4.282675
#
#                            timestamp  free_bikes  empty_slots  extra.uid  \
# 0  2025-07-01T19:18:19.376003+00:00Z          11            0   19738176
# 1  2025-07-01T19:18:19.377604+00:00Z           6            0  150125231
# 2  2025-07-01T19:18:19.376951+00:00Z           6            0   55599921
# 3  2025-07-01T19:18:19.375677+00:00Z           1            7    7145152
# 4  2025-07-01T19:18:19.375152+00:00Z           1            6    3812605
#
#   extra.number  extra.slots  \
# 0         8416            6
# 1         8470            8
# 2         8200            6
# 3         8403            8
# 4         8453            8
#
#                                      extra.bike_uids  extra.virtual
# 0  [47041, 823506, 46976, 46961, 46910, 828228, 4...          False
# 1       [82316, 840047, 46722, 46457, 47968, 829955]          False
# 2    [828253, 46967, 823632, 828964, 823601, 829990]          False
# 3                                            [46992]          False
# 4                                            [46830]          False

# %%
# Save the dataframe to a CSV file
df.to_csv('../data/city_bikes.csv', index=False)
